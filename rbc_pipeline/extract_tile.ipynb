# %%
# This generates a PIL image showing where the patches are on the kidney
wsi.preview(whitespace_threshold=245, whitespace_fraction=0.95)
# Out:
# /opt/miniconda3/envs/segmentation/lib/python3.10/site-packages/rich/live.py:256: UserWarning: install "ipywidgets"
# for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# /opt/miniconda3/envs/segmentation/lib/python3.10/site-packages/slideflow/plugin.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /opt/miniconda3/envs/segmentation/lib/python3.10/site-packages/slideflow/plugin.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ...

# %%
import slideflow as sf

# 1. Initialize WSI with stride_div for overlap
# stride_div=1.28 roughly equals a stride of 200 for 256px tiles
wsi = sf.WSI(
    path='/Users/edmundtsou/Desktop/JEFworks/jefworks-structure_segmentation/data/lab_kidney_data_ndpi/OTS-24-22043 - 2024-08-28 14.58.03.ndpi',
    tile_px=256,
    tile_um=64,
    stride_div=1.28, 
)

# 2. Extract tiles with whitespace filtering
# This skips any tile where more than 95% is "white" (above 245)
wsi.extract_tiles(
    tiles_dir='./filtered_kidney_tiles',
    whitespace_threshold=245,
    whitespace_fraction=0.95,
    img_format='jpg'
)
# Out:
# [15:09:20] INFO     No ROI for OTS-24-22043 - 2024-08-28 14.58.03, using whole slide.
# /opt/miniconda3/envs/segmentation/lib/python3.10/site-packages/slideflow/plugin.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /opt/miniconda3/envs/segmentation/lib/python3.10/site-packages/slideflow/plugin.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ...
