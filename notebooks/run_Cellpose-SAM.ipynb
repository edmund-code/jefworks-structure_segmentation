# %% [markdown]
# <a href="https://colab.research.google.com/github/edmund-code/jefworks-structure_segmentation/blob/main/notebooks/run_Cellpose-SAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cellpose-SAM: superhuman generalization for cellular segmentation
#
# Marius Pachitariu, Michael Rariden, Carsen Stringer
#
# [paper](https://www.biorxiv.org/content/10.1101/2025.04.28.651001v1) | [code](https://github.com/MouseLand/cellpose)
#
# This notebook shows how to process your own 2D or 3D images, saved on Google Drive.
#
# This notebook is adapted from the notebook by Pradeep Rajasekhar, inspired by the [ZeroCostDL4Mic notebook series](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).

# %% [markdown]
# ### Make sure you have GPU access enabled by going to Runtime -> Change Runtime Type -> Hardware accelerator and selecting GPU
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Mount your google drive
#
# Run this cell to connect your Google Drive to colab:
# * Click on the URL.
# * Sign in your Google Account.
#
# You will either have to:
# * copy the authorisation code and enter it into box below OR
# * in the new google colab, you can just click "Allow" and it should connect.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Then click on "Folder" icon on the Left, press the refresh button. Your Google Drive folder should now be available here as "gdrive".
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click on the triangle icon and it will allow you to access whole drive. Navigate to the folder containing your images. Once you are there, click on the three dots on the right of the folder and select "Copy Path"
#
# ![image.png](data:image/png;base64,...)
#
# Copy and paste this path in the **dir** string below

# %% [markdown]
# ### Install Cellpose-SAM

# %%
# !pip install git+https://www.github.com/mouseland/cellpose.git
# Out:
# Collecting git+https://www.github.com/mouseland/cellpose.git
#   Cloning https://www.github.com/mouseland/cellpose.git to /tmp/pip-req-build-b8j272jr
#   Running command git clone --filter=blob:none --quiet https://www.github.com/mouseland/cellpose.git /tmp/pip-req-build-b8j272jr
#   warning: redirecting to https://github.com/mouseland/cellpose.git/
#   Resolved https://www.github.com/mouseland/cellpose.git to commit 17fb25f40055ec2636aa708dc4cf6625b8b4735d
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (1.16.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (8.4.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (2025.12.12)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (4.67.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (0.24.0+cu126)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.8) (4.12.0.88)
# Collecting fastremap (from cellpose==4.0.8)
#   Downloading fastremap-1.17.7-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting imagecodecs (from cellpose==4.0.8)
#   Downloading imagecodecs-2026.1.1-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting roifile (from cellpose==4.0.8)
#   Downloading roifile-2025.12.12-py3-none-any.whl.metadata (6.0 kB)
# Collecting fill-voids (from cellpose==4.0.8)
#   Downloading fill_voids-2.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting segment_anything (from cellpose==4.0.8)
#   Downloading segment_anything-1.0-py3-none-any.whl.metadata (487 bytes)
# Requirement already satisfied: torch==2.9.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.0.8) (2.9.0+cu126)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.0.8) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.8) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.9.0->torchvision->cellpose==4.0.8) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.9.0->torchvision->cellpose==4.0.8) (3.0.3)
# Downloading fastremap-1.17.7-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 47.7 MB/s eta 0:00:00
# Downloading fill_voids-2.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 77.1 MB/s eta 0:00:00
# Downloading imagecodecs-2026.1.1-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 98.4 MB/s eta 0:00:00
# Downloading roifile-2025.12.12-py3-none-any.whl (16 kB)
# Downloading segment_anything-1.0-py3-none-any.whl (36 kB)
# Building wheels for collected packages: cellpose
#   Building wheel for cellpose (setup.py) ... done
#   Created wheel for cellpose: filename=cellpose-4.0.8-py3-none-any.whl size=212051 sha256=e57a1bb14c76fff7c1a9f3057770099230674ced204d4f33a2ae53c4e48282c7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j56klsl0/wheels/df/b6/31/a3013c44290eabb46f4c06d1efb19744124fcad2d59684ec5e
# Successfully built cellpose
# Installing collected packages: segment_anything, roifile, imagecodecs, fastremap, fill-voids, cellpose
# Successfully installed cellpose-4.0.8 fastremap-1.17.7 fill-voids-2.1.1 imagecodecs-2026.1.1 roifile-2025.12.12 segment_anything-1.0

# %% [markdown]
# Check GPU and instantiate model - will download weights.

# %%
import numpy as np
from cellpose import models, core, io, plot
from pathlib import Path
from tqdm import trange
import matplotlib.pyplot as plt
from natsort import natsorted

io.logger_setup() # run this to get printing of progress

#Check if colab notebook instance has GPU access
if core.use_gpu()==False:
  raise ImportError("No GPU access, change your runtime")

model = models.CellposeModel(gpu=True)
# Out:
# creating new log file
# 2026-01-08 14:57:37,538 [INFO] WRITING LOG OUTPUT TO /root/.cellpose/run.log
# 2026-01-08 14:57:37,539 [INFO]
# cellpose version: 	4.0.8
# platform:       	linux
# python version: 	3.12.12
# torch version:  	2.9.0+cu126
# 2026-01-08 14:57:37,774 [INFO] ** TORCH CUDA version installed and working. **
# 2026-01-08 14:57:37,775 [INFO] ** TORCH CUDA version installed and working. **
# 2026-01-08 14:57:37,776 [INFO] >>>> using GPU (CUDA)
# 2026-01-08 14:57:40,333 [INFO] Downloading: "https://huggingface.co/mouseland/cellpose-sam/resolve/main/cpsam" to /root/.cellpose/models/cpsam
# 100%|██████████| 1.15G/1.15G [00:03<00:00, 321MB/s]

# %% [markdown]
# Input directory with your images:

# %%
# *** change to your google drive folder path ***
dir = "/content/drive/MyDrive/JefWorks/Segmentation/Glomeruli_tiles"
dir = Path(dir)
if not dir.exists():
  raise FileNotFoundError("directory does not exist")

# *** change to your image extension ***
image_ext = ".jpg"

# list all files
files = natsorted([f for f in dir.glob("*"+image_ext) if "_masks" not in f.name and "_flows" not in f.name])

if(len(files)==0):
  raise FileNotFoundError("no image files found, did you specify the correct folder and extension?")
else:
  print(f"{len(files)} images in folder:")

for f in files:
  print(f.name)
# Out:
# 516 images in folder:
# OTS-24-22043 - 2024-08-28 14.58.03-8133-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-8133-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-8133-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-8133-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-8133-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-9295-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-9295-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-9295-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-9295-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-9295-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-9295-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-9295-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-9295-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-10457-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-10457-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-10457-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-10457-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-10457-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-10457-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-10457-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-10457-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-10457-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-10457-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-11619-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-12781-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-13943-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-15105-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-16267-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-17429-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-18591-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-19753-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-20915-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-22077-33697.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-23239-33697.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-24401-33697.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-25563-33697.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-26725-33697.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-27887-33697.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-29049-33697.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-10457.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-30211-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-10457.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-31373-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-9295.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-10457.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-32535-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-9295.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-10457.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-33697-32535.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-8133.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-9295.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-10457.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-34859-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-8133.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-9295.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-10457.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-30211.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-36021-31373.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-8133.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-9295.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-10457.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-37183-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-8133.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-9295.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-10457.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-38345-29049.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-9295.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-10457.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-39507-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-9295.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-10457.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-26725.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-40669-27887.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-10457.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-41831-25563.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-11619.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-23239.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-42993-24401.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-44155-12781.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-44155-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-44155-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-44155-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-44155-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-44155-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-44155-19753.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-44155-20915.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-44155-22077.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-45317-13943.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-45317-15105.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-45317-16267.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-45317-17429.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-45317-18591.jpg
# OTS-24-22043 - 2024-08-28 14.58.03-45317-19753.jpg

# %% [markdown]
# ## Run Cellpose-SAM on one image in folder
#
# Here are some of the parameters you can change:
#
# * ***flow_threshold*** is  the  maximum  allowed  error  of  the  flows  for  each  mask.   The  default  is 0.4.
#     *  **Increase** this threshold if cellpose is not returning as many masks as you’d expect (or turn off completely with 0.0)
#     *   **Decrease** this threshold if cellpose is returning too many ill-shaped masks.
#
# * ***cellprob_threshold*** determines proability that a detected object is a cell.   The  default  is 0.0.
#     *   **Decrease** this threshold if cellpose is not returning as many masks as you’d expect or if masks are too small
#     *   **Increase** this threshold if cellpose is returning too many masks esp from dull/dim areas.
#
# * ***tile_norm_blocksize*** determines the size of blocks used for normalizing the image. The default is 0, which means the entire image is normalized together.
#   You may want to change this to 100-200 pixels if you have very inhomogeneous brightness across your image.

# %%
path = "/content/drive/MyDrive/JefWorks/Segmentation/Glomeruli_tiles/OTS-24-22043 - 2024-08-28 14.58.03-8133-23239.jpg"
img = io.imread(path)

print(f'your image has shape: {img.shape}. Assuming channel dimension is last with {img.shape[-1]} channels')
# Out:
# your image has shape: (1024, 1024, 3). Assuming channel dimension is last with 3 channels

# %% [markdown]
# ### Channel Selection:
#
# - Use the dropdowns below to select the _zero-indexed_ channels of your image to segment. The order does not matter. Remember to rerun the cell after you edit the dropdowns.
#
# - If you have a histological image taken in brightfield, you don't need to adjust the channels.
#
# - If you have a fluroescent image with multiple stains, you should choose one channel with a cytoplasm/membrane stain, one channel with a nuclear stain, and set the third channel to `None`. Choosing multiple channels may produce segmentaiton of all the structures in the image. If you have retrained the model on your data with a thrid stain (described below), you can run segmentation with all channels.

# %%
first_channel = '1' # @param ['None', 0, 1, 2, 3, 4, 5]
second_channel = 'None' # @param ['None', 0, 1, 2, 3, 4, 5]
third_channel = 'None' # @param ['None', 0, 1, 2, 3, 4, 5]

# %%
selected_channels = []
for i, c in enumerate([first_channel, second_channel, third_channel]):
  if c == 'None':
    continue
  if int(c) > img.shape[-1]:
    assert False, 'invalid channel index, must have index greater or equal to the number of channels'
  if c != 'None':
    selected_channels.append(int(c))



img_selected_channels = np.zeros_like(img)
img_selected_channels[:, :, :len(selected_channels)] = img[:, :, selected_channels]


flow_threshold = 0.4
cellprob_threshold = 2
tile_norm_blocksize = 0

masks, flows, styles = model.eval(img_selected_channels, batch_size=32, diameter=80, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

fig = plt.figure(figsize=(12,5))
plot.show_segmentation(fig, img_selected_channels, masks, flows[0])
plt.tight_layout()
plt.show()
# Out:
# 2026-01-08 15:09:43,505 [INFO] processing image with (1024, 1024) HW, and 3 channels

# %%
num_masks = len(np.unique(masks)) - 1

print(f"Total Glomeruli detected in this tile: {num_masks}")
# Out:
# Total Glomeruli detected in this tile: 16

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Create a figure
plt.figure(figsize=(10, 10))

# 2. Display the original image first
plt.imshow(img)

# 3. Create a masked version of the masks for transparency
# We set background (0) to NaN so it's invisible
render_masks = masks.astype(float)
render_masks[render_masks == 0] = np.nan

# 4. Overlay the masks with a specific colormap and alpha (transparency)
# 'jet' or 'prism' works well to give each RBC a different color
plt.imshow(render_masks, cmap='prism', alpha=0.5)

plt.title("Manual Mask Overlay: Red Blood Cells")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Run Cellpose-SAM on folder of images
#
# if you have many large images, you may want to run them as a loop over images

# %% [markdown]
# if you have small images, you may want to load all of them first and then run, so that they can be batched together on the GPU

# %%
masks_ext = ".png" if image_ext == ".png" else ".tif"

print("loading images")
imgs = [io.imread(files[i]) for i in trange(10)]

print("running cellpose-SAM")
masks, flows, styles = model.eval(imgs, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

print("saving masks")
for i in trange(10):
    f = files[i]
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks[i])
# Out:
# loading images
# 100%|██████████| 10/10 [00:00<00:00, 60.86it/s]
# running cellpose-SAM
# 2026-01-08 15:12:11,262 [INFO] 0%|          | 0/10 [00:00<?, ?it/s]
# 2026-01-08 15:12:11,270 [INFO] processing image with (1024, 1024) HW, and 3 channels
# 2026-01-08 15:12:13,022 [INFO] processing image with (1024, 1024) HW, and 3 channels
# 2026-01-08 15:12:14,768 [INFO] processing image with (1024, 1024) HW, and 3 channels
# 2026-01-08 15:12:16,542 [INFO] processing image with (1024, 1024) HW, and 3 channels
# 2026-01-08 15:12:18,306 [INFO] processing image with (1024, 1024) HW, and 3 channels
# 2026-01-08 15:12:20,047 [INFO] processing image with (1024, 1024) HW, and 3 channels
# 2026-01-08 15:12:21,778 [INFO] processing image with (1024, 1024) HW, and 3 channels
# 2026-01-08 15:12:23,604 [INFO] processing image with (1024, 1024) HW, and 3 channels
# 2026-01-08 15:12:25,476 [INFO] processing image with (1024, 1024) HW, and 3 channels
# 2026-01-08 15:12:27,315 [INFO] processing image with (1024, 1024) HW, and 3 channels
# 2026-01-08 15:12:29,198 [INFO] 100%|##########| 10/10 [00:17<00:00,  1.79s/it]
# saving masks
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]

# %% [markdown]
# to save your masks for ImageJ, run the following code:

# %%
for i in trange(len(files)):
    f = files[i]
    masks0 = io.imsave(dir / (f.name + "_masks" + masks_ext))
    io.save_rois(masks0, f)
