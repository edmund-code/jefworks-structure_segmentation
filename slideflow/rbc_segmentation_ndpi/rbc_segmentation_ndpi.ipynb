# %%
# create annotations

import pandas as pd

# Define your data based on your filenames
data = {
    'patient': ['1', '2', '3', '4', '5', '6', '7', '8'],
    'category': ['Control', 'Control', 'Control', 'Control', 'Control', 'Control', 'Control', 'Control'],
    'dataset': ['train', 'train', 'train', 'train', 'train', 'train', 'train', 'train'],
    'slide': ['OTS-24-22043 - 2024-08-28 14.58.03', 'OTS-24-22043 - 2024-08-28 15.00.38', 'OTS-24-22043 - 2024-08-28 15.03.25', 'OTS-24-22043 - 2024-08-28 15.05.59', 'OTS-24-22043 - 2024-08-28 15.08.37', 'OTS-24-22043 - 2024-08-28 15.11.15', 'OTS-24-22043 - 2024-08-28 15.14.02', 'OTS-24-22043 - 2024-08-28 15.16.35']
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV (Slideflow usually looks for a comma-separated or tab-separated file)
df.to_csv('/Users/edmundtsou/Desktop/JEFworks/jefworks-structure_segmentation/rbc_segmentation_ndpi/annotations.csv', index=False)

print("Annotations file created at /Users/edmundtsou/Desktop/JEFworks/jefworks-structure_segmentation/rbc_segmentation")
display(df)
# Out:
# Annotations file created at /Users/edmundtsou/Desktop/JEFworks/jefworks-structure_segmentation/rbc_segmentation
#   patient category dataset                               slide
# 0       1  Control   train  OTS-24-22043 - 2024-08-28 14.58.03
# 1       2  Control   train  OTS-24-22043 - 2024-08-28 15.00.38
# 2       3  Control   train  OTS-24-22043 - 2024-08-28 15.03.25
# 3       4  Control   train  OTS-24-22043 - 2024-08-28 15.05.59
# 4       5  Control   train  OTS-24-22043 - 2024-08-28 15.08.37
# 5       6  Control   train  OTS-24-22043 - 2024-08-28 15.11.15
# 6       7  Control   train  OTS-24-22043 - 2024-08-28 15.14.02
# 7       8  Control   train  OTS-24-22043 - 2024-08-28 15.16.35

# %%
#create slideflow project

import slideflow as sf
import slideflow.util as sf_util


setattr(sf, 'util', sf_util)

P = sf.create_project(
  root='/Users/edmundtsou/Desktop/JEFworks/jefworks-structure_segmentation/rbc_segmentation_ndpi',
  annotations="/Users/edmundtsou/Desktop/JEFworks/jefworks-structure_segmentation/rbc_segmentation_ndpi/annotations.csv",
  slides='/Users/edmundtsou/Desktop/JEFworks/jefworks-structure_segmentation/data/lab_kidney_data_ndpi',
)
# Out:
# /opt/miniconda3/envs/segmentation/lib/python3.10/site-packages/slideflow/plugin.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [10:46:40] INFO     Setting up project at
#                     /Users/edmundtsou/Desktop/JEFworks/jefworks-structure_segmentation/rbc_segmentation_ndpi
#            INFO     Creating project at
#                     /Users/edmundtsou/Desktop/JEFworks/jefworks-structure_segmentation/rbc_segmentation_ndpi...
#            INFO     Saved dataset source MyProject to
#                     /Users/edmundtsou/Desktop/JEFworks/jefworks-structure_segmentation/rbc_segmentation_ndpi/datase
#                     ts.json

# %%
P.extract_tiles(
    tile_px=256,
    tile_um=64,
    save_tiles = True
)
# Out:
# /opt/miniconda3/envs/segmentation/lib/python3.10/site-packages/rich/live.py:256: UserWarning: install "ipywidgets"
# for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [14:40:10] INFO     Slide reading backend: libvips
#            INFO     Filtering tiles by grayspace fraction
#            INFO     Working on dataset source MyProject...
#            INFO     Extracting tiles from 8 slides (tile_px=256, tile_um=64)
#            INFO     Using 8 processes (pool=spawn)
#            INFO     No ROI for OTS-24-22043 - 2024-08-28 15.00.38, using whole slide.
# ...
